# %% [markdown]
# ### Simulating Physics Based Model

# %%
import pybamm
import numpy as np

# %%
def my_current(t):
    current = pybamm.sin(2 * np.pi * t / 60)
    return current

# %%
options = {"thermal": "x-full"}
model = pybamm.lithium_ion.SPMe(options=options)

# %%
parameter_values = model.default_parameter_values
parameter_values
# Out:
# {'1 + dlnf/dlnc': 1.0,
#  'Ambient temperature [K]': 298.15,
#  'Bulk solvent concentration [mol.m-3]': 2636.0,
#  'Cation transference number': 0.4,
#  'Cell cooling surface area [m2]': 0.0569,
#  'Cell volume [m3]': 7.8e-06,
#  'Current function [A]': 0.680616,
#  'EC diffusivity [m2.s-1]': 2e-18,
#  'EC initial concentration in electrolyte [mol.m-3]': 4541.0,
#  'Edge heat transfer coefficient [W.m-2.K-1]': 0.3,
#  'Electrode height [m]': 0.13699999999999998,
#  'Electrode width [m]': 0.207,
#  'Electrolyte conductivity [S.m-1]': <function electrolyte_conductivity_Capiglia1999 at 0x00000146CE5FD280>,
#  'Electrolyte diffusivity [m2.s-1]': <function electrolyte_diffusivity_Capiglia1999 at 0x00000146CE5FD3A0>,
#  'Initial concentration in electrolyte [mol.m-3]': 1000.0,
#  'Initial concentration in negative electrode [mol.m-3]': 19986.609595075,
#  'Initial concentration in positive electrode [mol.m-3]': 30730.755438556498,
#  'Initial inner SEI thickness [m]': 2.5e-09,
#  'Initial outer SEI thickness [m]': 2.5e-09,
#  'Initial temperature [K]': 298.15,
#  'Inner SEI electron conductivity [S.m-1]': 8.95e-14,
#  'Inner SEI lithium interstitial diffusivity [m2.s-1]': 1.0000000000000001e-20,
#  'Inner SEI open-circuit potential [V]': 0.1,
#  'Inner SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Inner SEI reaction proportion': 0.5,
#  'Lithium interstitial reference concentration [mol.m-3]': 15.0,
#  'Lower voltage cut-off [V]': 3.105,
#  'Maximum concentration in negative electrode [mol.m-3]': 24983.2619938437,
#  'Maximum concentration in positive electrode [mol.m-3]': 51217.9257309275,
#  'Negative current collector conductivity [S.m-1]': 59600000.0,
#  'Negative current collector density [kg.m-3]': 8954.0,
#  'Negative current collector specific heat capacity [J.kg-1.K-1]': 385.0,
#  'Negative current collector surface heat transfer coefficient [W.m-2.K-1]': 0.0,
#  'Negative current collector thermal conductivity [W.m-1.K-1]': 401.0,
#  'Negative current collector thickness [m]': 2.5e-05,
#  'Negative electrode Bruggeman coefficient (electrode)': 1.5,
#  'Negative electrode Bruggeman coefficient (electrolyte)': 1.5,
#  'Negative electrode OCP [V]': <function graphite_mcmb2528_ocp_Dualfoil1998 at 0x00000146CE5EBDC0>,
#  'Negative electrode OCP entropic change [V.K-1]': <function graphite_entropic_change_Moura2016 at 0x00000146CE5FD040>,
#  'Negative electrode active material volume fraction': 0.6,
#  'Negative electrode cation signed stoichiometry': -1.0,
#  'Negative electrode charge transfer coefficient': 0.5,
#  'Negative electrode conductivity [S.m-1]': 100.0,
#  'Negative electrode density [kg.m-3]': 1657.0,
#  'Negative electrode diffusivity [m2.s-1]': <function graphite_mcmb2528_diffusivity_Dualfoil1998 at 0x00000146CE5EB9D0>,
#  'Negative electrode double-layer capacity [F.m-2]': 0.2,
#  'Negative electrode electrons in reaction': 1.0,
#  'Negative electrode exchange-current density [A.m-2]': <function graphite_electrolyte_exchange_current_density_Dualfoil1998 at 0x00000146CE5EBEE0>,
#  'Negative electrode porosity': 0.3,
#  'Negative electrode reaction-driven LAM factor [m3.mol-1]': 0.0,
#  'Negative electrode specific heat capacity [J.kg-1.K-1]': 700.0,
#  'Negative electrode thermal conductivity [W.m-1.K-1]': 1.7,
#  'Negative electrode thickness [m]': 0.0001,
#  'Negative particle radius [m]': 1e-05,
#  'Negative tab centre y-coordinate [m]': 0.06,
#  'Negative tab centre z-coordinate [m]': 0.13699999999999998,
#  'Negative tab heat transfer coefficient [W.m-2.K-1]': 10.0,
#  'Negative tab width [m]': 0.04,
#  'Nominal cell capacity [A.h]': 0.680616,
#  'Number of cells connected in series to make a battery': 1.0,
#  'Number of electrodes connected in parallel to make a cell': 1.0,
#  'Outer SEI open-circuit potential [V]': 0.8,
#  'Outer SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Outer SEI solvent diffusivity [m2.s-1]': 2.5000000000000002e-22,
#  'Positive current collector conductivity [S.m-1]': 35500000.0,
#  'Positive current collector density [kg.m-3]': 2707.0,
#  'Positive current collector specific heat capacity [J.kg-1.K-1]': 897.0,
#  'Positive current collector surface heat transfer coefficient [W.m-2.K-1]': 0.0,
#  'Positive current collector thermal conductivity [W.m-1.K-1]': 237.0,
#  'Positive current collector thickness [m]': 2.5e-05,
#  'Positive electrode Bruggeman coefficient (electrode)': 1.5,
#  'Positive electrode Bruggeman coefficient (electrolyte)': 1.5,
#  'Positive electrode OCP [V]': <function lico2_ocp_Dualfoil1998 at 0x00000146CE5FD0D0>,
#  'Positive electrode OCP entropic change [V.K-1]': <function lico2_entropic_change_Moura2016 at 0x00000146CE5FD1F0>,
#  'Positive electrode active material volume fraction': 0.5,
#  'Positive electrode cation signed stoichiometry': -1.0,
#  'Positive electrode charge transfer coefficient': 0.5,
#  'Positive electrode conductivity [S.m-1]': 10.0,
#  'Positive electrode density [kg.m-3]': 3262.0,
#  'Positive electrode diffusivity [m2.s-1]': <function lico2_diffusivity_Dualfoil1998 at 0x00000146C8AFAF70>,
#  'Positive electrode double-layer capacity [F.m-2]': 0.2,
#  'Positive electrode electrons in reaction': 1.0,
#  'Positive electrode exchange-current density [A.m-2]': <function lico2_electrolyte_exchange_current_density_Dualfoil1998 at 0x00000146CE5FD160>,
#  'Positive electrode porosity': 0.3,
#  'Positive electrode reaction-driven LAM factor [m3.mol-1]': 0.0,
#  'Positive electrode specific heat capacity [J.kg-1.K-1]': 700.0,
#  'Positive electrode thermal conductivity [W.m-1.K-1]': 2.1,
#  'Positive electrode thickness [m]': 0.0001,
#  'Positive particle radius [m]': 1e-05,
#  'Positive tab centre y-coordinate [m]': 0.147,
#  'Positive tab centre z-coordinate [m]': 0.13699999999999998,
#  'Positive tab heat transfer coefficient [W.m-2.K-1]': 10.0,
#  'Positive tab width [m]': 0.04,
#  'Ratio of inner and outer SEI exchange current densities': 1.0,
#  'Reference temperature [K]': 298.15,
#  'SEI kinetic rate constant [m.s-1]': 1e-12,
#  'SEI open-circuit potential [V]': 0.4,
#  'SEI reaction exchange current density [A.m-2]': 1.5e-07,
#  'SEI resistivity [Ohm.m]': 200000.0,
#  'Separator Bruggeman coefficient (electrolyte)': 1.5,
#  'Separator density [kg.m-3]': 397.0,
#  'Separator porosity': 1.0,
#  'Separator specific heat capacity [J.kg-1.K-1]': 700.0,
#  'Separator thermal conductivity [W.m-1.K-1]': 0.16,
#  'Separator thickness [m]': 2.5e-05,
#  'Total heat transfer coefficient [W.m-2.K-1]': 10.0,
#  'Typical current [A]': 0.680616,
#  'Typical electrolyte concentration [mol.m-3]': 1000.0,
#  'Upper voltage cut-off [V]': 4.1}

# %%
# defining RMSE
import math

def RMSE(true_voltage, model_voltage):
    res = 0
    n = len(true_voltage)
    for i in range(n):
        res+= (true_voltage[i]-model_voltage[i])**2
    res = res/n
    return math.sqrt(res)

# %%
# defining array of C_rates
C_Rates = [0.1, 0.2, 0.4, 0.8, 1, 2, 4, 6, 8, 10]


NSOC = []
Temp = []
Voltage = []
OCV = []
C_Rate = []

SPMT_RMSE = []

n = len(C_Rates)


for i in range (n):
    sim = pybamm.Simulation(model, parameter_values=parameter_values, C_rate = C_Rates[i])
    sim.solve([0,3600])
    nsoc = sim.solution["Negative electrode SOC"].entries
    temp = sim.solution["Negative electrode temperature [K]"].entries[-1]
    voltage = sim.solution["Terminal voltage [V]"].entries
    ocv = sim.solution["Measured open circuit voltage [V]"].entries
    
    rmse = RMSE(ocv,voltage) 
    SPMT_RMSE.append(rmse)
    
    for j in range(len(nsoc)):
        C_Rate.append(C_Rates[i])
        NSOC.append(nsoc[j])
        Temp.append(temp[j])
        Voltage.append(voltage[j])
        OCV.append(ocv[j])

# %%
# creating a dataframe and storing the results

import pandas as pd

df = pd.DataFrame()
df['C_Rate'] = C_Rate
df['NSOC'] = NSOC
df['Temp'] = Temp
df['Voltage'] = Voltage
df['OCV'] = OCV

# %%
df.head()
# Out:
#    C_Rate      NSOC        Temp   Voltage       OCV
# 0     0.1  0.800000  298.150000  3.841727  3.851824
# 1     0.1  0.799397  298.153985  3.840125  3.850778
# 2     0.1  0.798793  298.158054  3.839417  3.850216
# 3     0.1  0.798190  298.162147  3.838888  3.849725
# 4     0.1  0.797586  298.166249  3.838417  3.849262

# %%
# storing result into spmt.csv file
df.to_csv(r"spmt_data.csv")

# %%
# Creating C_Rate VS RMSE csv
df2 = pd.DataFrame()
df2['C_Rate'] = C_Rates
df2['SPMT_RMSE'] = SPMT_RMSE
df2.head(10)
# Out:
#    C_Rate  SPMT_RMSE
# 0     0.1   0.010783
# 1     0.2   0.021097
# 2     0.4   0.038985
# 3     0.8   0.063912
# 4     1.0   0.073439
# 5     2.0   0.107727
# 6     4.0   0.150256
# 7     6.0   0.179473
# 8     8.0   0.206541
# 9    10.0   0.226304

# %%
# storing result into spmt_rmse.csv
df2.to_csv(r"spmt_rmse.csv")

# %% [markdown]
# ### Simulating Hybrid Model

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv(r"spmt_data.csv")
df = pd.DataFrame(data)

# Split data
x = df.drop(df.columns[[3,4,5]], axis = 1)
y = df.drop(df.columns[[0,1,2,3,4]], axis = 1)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)
# Out:
#    Unnamed: 0  C_Rate      NSOC
# 0           0     0.1  0.800000
# 1           1     0.1  0.799397
# 2           2     0.1  0.798793
# 3           3     0.1  0.798190
# 4           4     0.1  0.797586
#         OCV
# 0  3.851824
# 1  3.850778
# 2  3.850216
# 3  3.849725
# 4  3.849262

# %%
import tensorflow as tf
from tensorflow import keras

# defining model
model = keras.Sequential([
    keras.layers.Dense(32, activation = 'relu', input_dim = 3),
    keras.layers.Dense(32, activation = 'relu'),
    keras.layers.Dense(1, activation = 'linear')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

# compiling model
model.compile(optimizer = 'adam',
             loss = 'mean_squared_error',
             metrics = ['mean_squared_error'])

# fitting model
model.fit(x_train,y_train, epochs = 250)
# Out:
# Epoch 1/250
# 16/16 [==============================] - 1s 1ms/step - loss: 8864.8834 - mean_squared_error: 8864.8834
# Epoch 2/250
# 16/16 [==============================] - 0s 1ms/step - loss: 721.3788 - mean_squared_error: 721.3788
# Epoch 3/250
# 16/16 [==============================] - 0s 533us/step - loss: 97.8886 - mean_squared_error: 97.8886
# Epoch 4/250
# 16/16 [==============================] - 0s 533us/step - loss: 39.9510 - mean_squared_error: 39.9510
# Epoch 5/250
# 16/16 [==============================] - 0s 533us/step - loss: 7.8772 - mean_squared_error: 7.8772
# Epoch 6/250
# 16/16 [==============================] - 0s 1ms/step - loss: 5.2978 - mean_squared_error: 5.2978
# Epoch 7/250
# 16/16 [==============================] - 0s 1ms/step - loss: 4.1662 - mean_squared_error: 4.1662
# Epoch 8/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.8590 - mean_squared_error: 3.8590
# Epoch 9/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.9700 - mean_squared_error: 3.9700
# Epoch 10/250
# 16/16 [==============================] - 0s 533us/step - loss: 3.7824 - mean_squared_error: 3.7824
# Epoch 11/250
# 16/16 [==============================] - 0s 533us/step - loss: 3.8646 - mean_squared_error: 3.8646
# Epoch 12/250
# 16/16 [==============================] - 0s 533us/step - loss: 3.9088 - mean_squared_error: 3.9088
# Epoch 13/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.8946 - mean_squared_error: 3.8946
# Epoch 14/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.8949 - mean_squared_error: 3.8949
# Epoch 15/250
# 16/16 [==============================] - 0s 533us/step - loss: 3.5622 - mean_squared_error: 3.5622
# Epoch 16/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.8471 - mean_squared_error: 3.8471
# Epoch 17/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.6942 - mean_squared_error: 3.6942
# Epoch 18/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.6199 - mean_squared_error: 3.6199
# Epoch 19/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.5307 - mean_squared_error: 3.5307
# Epoch 20/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.1753 - mean_squared_error: 3.1753
# Epoch 21/250
# 16/16 [==============================] - 0s 1ms/step - loss: 3.0508 - mean_squared_error: 3.0508
# Epoch 22/250
# 16/16 [==============================] - 0s 1ms/step - loss: 2.9792 - mean_squared_error: 2.9792
# Epoch 23/250
# 16/16 [==============================] - 0s 533us/step - loss: 2.3356 - mean_squared_error: 2.3356
# Epoch 24/250
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6050 - mean_squared_error: 1.6050
# Epoch 25/250
# 16/16 [==============================] - 0s 1ms/step - loss: 1.1968 - mean_squared_error: 1.1968
# Epoch 26/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8685 - mean_squared_error: 0.8685
# Epoch 27/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4367 - mean_squared_error: 0.4367
# Epoch 28/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2583 - mean_squared_error: 0.2583
# Epoch 29/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2130 - mean_squared_error: 0.2130
# Epoch 30/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1373 - mean_squared_error: 0.1373
# Epoch 31/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0899 - mean_squared_error: 0.0899
# Epoch 32/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0776 - mean_squared_error: 0.0776
# Epoch 33/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0716 - mean_squared_error: 0.0716
# Epoch 34/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0806 - mean_squared_error: 0.0806
# Epoch 35/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0930 - mean_squared_error: 0.0930
# Epoch 36/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0993 - mean_squared_error: 0.0993
# Epoch 37/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0539 - mean_squared_error: 0.0539
# Epoch 38/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0565 - mean_squared_error: 0.0565
# Epoch 39/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0485 - mean_squared_error: 0.0485
# Epoch 40/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0624 - mean_squared_error: 0.0624
# Epoch 41/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0670 - mean_squared_error: 0.0670
# Epoch 42/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0533 - mean_squared_error: 0.0533
# Epoch 43/250
# 16/16 [==============================] - 0s 533us/step - loss: 0.0415 - mean_squared_error: 0.0415
# Epoch 44/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0406 - mean_squared_error: 0.0406
# Epoch 45/250
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0376 - mean_squared_error: 0.0376
# Epoch 46/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0417 - mean_squared_error: 0.0417
# Epoch 47/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0566 - mean_squared_error: 0.0566
# Epoch 48/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0363 - mean_squared_error: 0.0363
# Epoch 49/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0344 - mean_squared_error: 0.0344
# Epoch 50/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_squared_error: 0.0309
# Epoch 51/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_squared_error: 0.0309
# Epoch 52/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0303 - mean_squared_error: 0.0303
# Epoch 53/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Epoch 54/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0286 - mean_squared_error: 0.0286
# Epoch 55/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0308 - mean_squared_error: 0.0308
# Epoch 56/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 57/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0295 - mean_squared_error: 0.0295
# Epoch 58/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_squared_error: 0.0279
# Epoch 59/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0304 - mean_squared_error: 0.0304
# Epoch 60/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0278
# Epoch 61/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234
# Epoch 62/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0316 - mean_squared_error: 0.0316
# Epoch 63/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Epoch 64/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0364 - mean_squared_error: 0.0364
# Epoch 65/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 66/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 67/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 68/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0309 - mean_squared_error: 0.0309
# Epoch 69/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0338 - mean_squared_error: 0.0338
# Epoch 70/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_squared_error: 0.0249
# Epoch 71/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0202 - mean_squared_error: 0.0202
# Epoch 72/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236
# Epoch 73/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0207 - mean_squared_error: 0.0207
# Epoch 74/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_squared_error: 0.0201
# Epoch 75/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0214 - mean_squared_error: 0.0214
# Epoch 76/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0199 - mean_squared_error: 0.0199
# Epoch 77/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267
# Epoch 78/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236
# Epoch 79/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0258 - mean_squared_error: 0.0258
# Epoch 80/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0275 - mean_squared_error: 0.0275
# Epoch 81/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 82/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0310
# Epoch 83/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 84/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 85/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_squared_error: 0.0219
# Epoch 86/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 87/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 88/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0243 - mean_squared_error: 0.0243
# Epoch 89/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229
# Epoch 90/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 91/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 92/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 93/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230
# Epoch 94/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 95/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 96/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 97/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0180 - mean_squared_error: 0.0180
# Epoch 98/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 99/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 100/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0210 - mean_squared_error: 0.0210
# Epoch 101/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 102/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 103/250
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0253 - mean_squared_error: 0.0253
# Epoch 104/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 105/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 106/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_squared_error: 0.0266
# Epoch 107/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0440 - mean_squared_error: 0.0440
# Epoch 108/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Epoch 109/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Epoch 110/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 111/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 112/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 113/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 114/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0278 - mean_squared_error: 0.0278
# Epoch 115/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 116/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Epoch 117/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0254 - mean_squared_error: 0.0254
# Epoch 118/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 119/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0302 - mean_squared_error: 0.0302
# Epoch 120/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 121/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0206 - mean_squared_error: 0.0206
# Epoch 122/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 123/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0203 - mean_squared_error: 0.0203
# Epoch 124/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 125/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0277 - mean_squared_error: 0.0277
# Epoch 126/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 127/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0294 - mean_squared_error: 0.0294
# Epoch 128/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0239 - mean_squared_error: 0.0239
# Epoch 129/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 130/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 131/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 132/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 133/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 134/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 135/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0203 - mean_squared_error: 0.0203
# Epoch 136/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 137/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234
# Epoch 138/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 139/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 140/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_squared_error: 0.0136
# Epoch 141/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 142/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 143/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 144/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0226 - mean_squared_error: 0.0226
# Epoch 145/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 146/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 147/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0136 - mean_squared_error: 0.0136
# Epoch 148/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 149/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_squared_error: 0.0145
# Epoch 150/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 151/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0209 - mean_squared_error: 0.0209
# Epoch 152/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0183 - mean_squared_error: 0.0183
# Epoch 153/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 154/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238
# Epoch 155/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 156/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0252 - mean_squared_error: 0.0252
# Epoch 157/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0191 - mean_squared_error: 0.0191
# Epoch 158/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Epoch 159/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0180 - mean_squared_error: 0.0180
# Epoch 160/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 161/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 162/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0203 - mean_squared_error: 0.0203
# Epoch 163/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 164/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 165/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Epoch 166/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 167/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 168/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 169/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 170/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 171/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 172/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 173/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0207 - mean_squared_error: 0.0207
# Epoch 174/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 175/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 176/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0137 - mean_squared_error: 0.0137
# Epoch 177/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 178/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0262 - mean_squared_error: 0.0262
# Epoch 179/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 180/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 181/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 182/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 183/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 184/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 185/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 186/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 187/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 188/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 189/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 190/250
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 191/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 192/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 193/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 194/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0212 - mean_squared_error: 0.0212
# Epoch 195/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0198 - mean_squared_error: 0.0198
# Epoch 196/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 197/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 198/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 199/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 200/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 201/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0340 - mean_squared_error: 0.0340
# Epoch 202/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 203/250
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 204/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 205/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 206/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 207/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 208/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 209/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 210/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 211/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 212/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 213/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 214/250
# 16/16 [==============================] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.00 - 0s 2ms/step - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 215/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 216/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 217/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 218/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 219/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 220/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 221/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_squared_error: 0.0113
# Epoch 222/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 223/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 224/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 225/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 226/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 227/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 228/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 229/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_squared_error: 0.0219
# Epoch 230/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 231/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 232/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 233/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 234/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 235/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 236/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 237/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 238/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 239/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_squared_error: 0.0266
# Epoch 240/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 241/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 242/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 243/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 244/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 245/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 246/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 247/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 248/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_squared_error: 0.0117
# Epoch 249/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 250/250
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_squared_error: 0.0127

# %%
score = model.evaluate(x_test, y_test)
score
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# [0.010027347132563591, 0.010027347132563591]

# %%
y_predicted = model.predict(x)
df['Hybrid_Predicted_Voltage'] = y_predicted
df.head()
# Out:
#    Unnamed: 0  C_Rate      NSOC        Temp   Voltage       OCV  \
# 0           0     0.1  0.800000  298.150000  3.841727  3.851824
# 1           1     0.1  0.799397  298.153985  3.840125  3.850778
# 2           2     0.1  0.798793  298.158054  3.839417  3.850216
# 3           3     0.1  0.798190  298.162147  3.838888  3.849725
# 4           4     0.1  0.797586  298.166249  3.838417  3.849262
#
#    Hybrid_Predicted_Voltage
# 0                  3.860100
# 1                  3.782901
# 2                  3.843900
# 3                  3.869452
# 4                  3.851907

# %%
# storing result into hybrid.csv file
df.to_csv(r"hybrid_data.csv")

# %%
Hybrid_RMSE = []

m = len(df['C_Rate'])

for i in range(n):
    c_rate = C_Rates[i]
    ocv = []
    hybrid = []
    for j in range(m):
        if df['C_Rate'][j] == c_rate:
            ocv.append(df['OCV'][j])
            hybrid.append(df['Hybrid_Predicted_Voltage'][j])
            
    rmse = RMSE(ocv , hybrid)
    Hybrid_RMSE.append(rmse)

# %%
data = pd.read_csv(r"spmt_rmse.csv")
df2 = pd.DataFrame(data)
df2['Hybrid_RMSE'] = Hybrid_RMSE
df2.head(10)
# Out:
#    Unnamed: 0  C_Rate  SPMT_RMSE  Hybrid_RMSE
# 0           0     0.1   0.010783     0.014332
# 1           1     0.2   0.021097     0.020271
# 2           2     0.4   0.038985     0.025802
# 3           3     0.8   0.063912     0.094791
# 4           4     1.0   0.073439     0.160272
# 5           5     2.0   0.107727     0.165108
# 6           6     4.0   0.150256     0.110694
# 7           7     6.0   0.179473     0.121411
# 8           8     8.0   0.206541     0.135617
# 9           9    10.0   0.226304     0.140963

# %%
def RER(RMSE_SPMT,RMSE_Hybrid):
    rer = ((RMSE_SPMT - RMSE_Hybrid)/RMSE_SPMT) * 100
    return rer

# %%
ReR = []

m = len(df2['SPMT_RMSE'])
for i in range(m):
    rer = RER(df2['SPMT_RMSE'][i],df2['Hybrid_RMSE'][i])
    ReR.append(rer)
    
df2['RER']=ReR

# %%
# storing result into hybrid_rmse.csv
df2.to_csv(r"hybrid_rmse.csv")

# %%
df2.head(10)
# Out:
#    Unnamed: 0  C_Rate  SPMT_RMSE  Hybrid_RMSE         RER
# 0           0     0.1   0.010783     0.014332  -32.912043
# 1           1     0.2   0.021097     0.020271    3.914582
# 2           2     0.4   0.038985     0.025802   33.814043
# 3           3     0.8   0.063912     0.094791  -48.314656
# 4           4     1.0   0.073439     0.160272 -118.238872
# 5           5     2.0   0.107727     0.165108  -53.265368
# 6           6     4.0   0.150256     0.110694   26.329824
# 7           7     6.0   0.179473     0.121411   32.351405
# 8           8     8.0   0.206541     0.135617   34.338912
# 9           9    10.0   0.226304     0.140963   37.710943
